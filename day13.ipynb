# %%
# import pandas as pd

# # pd.DataFrame({})
# # pd.Series([]), #index


# # data = {
# #     "key": value
# # }

# # s = pd.Series(data)


# data = {
#     "Name": ["John", "Asha", "Rahul"],
#     "Age": [22, 24, 21],
#     "Salary": [50000, 60000, 55000]
# }

# df = pd.DataFrame(data)
# df["Bonus"] = df["Salary"] * 0.10
# df.drop("Bonus", axis=1, inplace=True)

# # print(df.head())
# # print(df.tail())
# # print(df.info())
# Out:
#     Name  Age  Salary
# 2  Rahul   21   55000

# %%
employeeData = [
    {"name": "Sathya", "salary": 82000},
    {"name": "Sanjay", "salary": 90000},
    {"name": "Prakash", "salary": 75000},
    {"name": "Karan", "salary": 81000},
]

high_paid_salary = []

# print("employees",employeeData.salary)
for i in employeeData:
    if(i["salary"] > 80000):
        high_paid_salary.append(i)

print("High salary", high_paid_salary)


import pandas as ps

data = {
    "Name": ["John", "Asha", "Rahul"],
    "Age": [22, 24, 21],
    "Salary": [50000, 60000, 55000]
}

employeesData = ps.DataFrame(data)

print(employeesData[employeesData["Salary"] > 50000])
# Out:
# High salary [{'name': 'Sathya', 'salary': 82000}, {'name': 'Sanjay', 'salary': 90000}, {'name': 'Karan', 'salary': 81000}]
#     Name  Age  Salary
# 1   Asha   24   60000
# 2  Rahul   21   55000

# %%
import pandas as ps

s = ps.Series([66, 76, 86, 96], index = ["Madurai", "Chennai", "Coimbatore", "Trichy"])
# print("series", s)
# print("series", s["Trichy"])
# print("series", s["Chennai":"Coimbatore"])
# Out:
# series Chennai       76
# Coimbatore    86
# dtype: int64

# %%
# studentAttendanceDict = [
#     {"Name": "Sanjay", "Attendance":89}
# ]

# studentAttendance = {
#     "Name": ["Sanjay", "Praksh", "Santhosh", "Aswathaman"],
#     "Attendance":[89, 100, 89, 95]
# }

# studentDetails = ps.DataFrame(studentAttendance)

# print(studentDetails[studentDetails["Attendance"] > 90])


data = {
    "Name": ["John", "Asha", "Rahul", "Arun"],
    "Age": [22, 24, 21, None],
    "Salary": [50000, 60000, 55000, None]
}

ed = ps.DataFrame(data)

ed["Hike"] = ed["Salary"]*0.20

ed.drop("Age", axis = 1, inplace=True)

print(ed)

# print(ed.head(2))
# print(ed.tail(1))
# print(ed.info())
# Out:
#     Name   Salary     Hike
# 0   John  50000.0  10000.0
# 1   Asha  60000.0  12000.0
# 2  Rahul  55000.0  11000.0
# 3   Arun      NaN      NaN

# %%
# MArch and june

# exception handling


# try:
#     amount = int(input("Enter your amount: "))
#     print("amount", amount)
#     n = [10,11,12,13]
#     print(n[4])
# except Exception as e:
#     print(e)


# try:
#     amount = int(input("Enter your amount: "))
#     print("amount", amount)
# except:
#     print("Invalid input value")
# else:
#     print("Amount collected successfully")

# try:
#     age = int(input("Enter your age: "))
#     print("age", age)
# except:
#     print("Invalid input value")
# finally:
#     print("age data program run successfully")


# age = int(input("Enter your age: "))

# if age < 0:
#     raise ValueError("Invalid age data")
# if age > 16:
#     print("You are allowed to watch the movie")
# else:
#     print("Not allowed")


print("Please insert your card!")

print("Select your language: English")

balance = 10000

try:
    account = input("Select your account: S/C ")
    if(account.lower() == "s"):
        print("Savings account")
    elif(account.lower() == "c"):
        print("Current account")
    else:
        raise Exception("Please select valid account type")

    amount = int(input("Enter your amount: "))

    if(amount > balance):
        raise ValueError("Insufficent balance")
    elif(amount < 100):
        raise ValueError("Please enter valid amount value")

    pin = input("Enter your pin: ")

    if(pin != "1111"):
        raise ValueError("Please enter valid pin number")
    
    print("Please collect your cash: ", amount)

except Exception as err:
    print(err)
else:
    print("Amount collected successfully")
finally:
    print("Please take your card. Thank you!")
# Out:
# Please insert your card!
# Select your language: English
# Savings account
# Please enter valid pin number
# Please take your card. Thank you!
