# %%
import pandas as pd

# students = {
#     "Name": ["John", "Asha", "Rahul"],
#     "Mark": [90, 95, 85],
#     "City": ["Chennai", "Madurai", "Coimbatore"]
# }

# df = pd.DataFrame(students)

# print(df)


# df.to_csv("students_data.csv", index=False) #create csv
# df = pd.read_csv("students_data.csv") # read csv

# print(df)

# df.head(1)
# df.tail(1)

# print(df.columns)


#select single and multiple columns

# print(df["Name"])
# print(df[["Name", "Mark"]])

#filter rows

# print(df[df["Mark"] > 90])

#add column
# df["Result"] = "Pass"

# print(df)
# Out:
#     Name  Mark        City Result
# 0   John    90     Chennai   Pass
# 1   Asha    95     Madurai   Pass
# 2  Rahul    85  Coimbatore   Pass

# %%
#Null handling

import pandas as pd
import numpy as np

# data = {
#     "Name": ["John", "Asha", "Rahul", "Priya"],
#     "Age": [25, np.nan, 28, 35],
#     "Salary": [50000, 45000, np.nan, 55000]
# }

# df = pd.DataFrame(data)

# print(df)

# df.isnull()  # find null
# df.isnull().sum() #count null

# df.dropna() #remove null rows

# df.fillna(0) #fill null values

# df["Age"].fillna(       # fill with mean
#     df["Age"].mean(),
#     inplace=True
# )
# df["Salary"].fillna(       # fill with mean
#     df["Salary"].mean(),
#     inplace=True
# )





# #fill strings

data = {
    "Name":["John",None,"Rahul"]
}

df = pd.DataFrame(data)

df["Name"].fillna("Unknown")

print("df", df)

# #duplicate data 

data = {
    "Name":["John","John","Asha"],
    "Mark":[90,90,95]
}

df.duplicated()

df.drop_duplicates()

# df.info()

# df.describe()
# Out:
# df     Name
# 0   John
# 1   None
# 2  Rahul
