# %%
import pandas as pd

# userData = {
#     "customer_id": [1, 2, 3, 4],
#     "name": ["Arun", "Priya", "Kumar", "Divya"],
#     "city": ["Chennai", "Bangalore", "Mumbai", "Delhi"]
# }

# orderedData = {
#     "customer_id": [1, 2, 2, 5],
#     "product": ["Laptop", "Mobile", "Tablet", "Watch"],
#     "amount": [50000, 20000, 15000, 10000]
# }

# customers = pd.DataFrame(userData)
# orders = pd.DataFrame(orderedData)

# print(customers)
# print(orders)

# pd.merge(
#     left,
#     right,
#     how,
#     on
# )

# pd.merge(
#     customers,
#     orders,
#     on="customer_id",
#     how="inner",
# )

# pd.merge(
#     customers,
#     orders,
#     on="customer_id",
#     how="left",
# )

# pd.merge(
#     customers,
#     orders,
#     on="customer_id",
#     how="right",
# )

# pd.merge(
#     customers,
#     orders,
#     on="customer_id",
#     how="outer",
# )


# Multiple key merge

# sales1 = pd.DataFrame({
#     "customer_id": [1, 1],
#     "product_id": [101, 102],
#     "qty": [2, 1]
# })

# sales2 = pd.DataFrame({
#     "customer_id": [1, 1],
#     "product_id": [101, 102],
#     "price": [500, 700]
# })

# pd.merge(
#     sales1,
#     sales2,
#     on=["customer_id", "product_id"]
# )


# DIFFERENT COLUMN NAMES
# customers = pd.DataFrame({
#     "cust_id": [1, 2],
#     "name": ["Arun", "Priya"]
# })

# orders = pd.DataFrame({
#     "customer_id": [1, 2],
#     "amount": [1000, 2000]
# })

# m = pd.merge(
#     customers,
#     orders,
#     left_on = "cust_id",
#     right_on = "customer_id"
# )

# print(m)


# DUPLICATE COLUMN HANDLING

# df1 = pd.DataFrame({
#     "id": [1],
#     "city": ["Chennai"]
# })

# df2 = pd.DataFrame({
#     "id": [1],
#     "city": ["Mumbai"]
# })

# pd.merge(
#     df1,
#     df2,
#     on="id",
#     suffixes = ["_living", "_ordered"]
# )



# Concat
# Row-wise
# jan_sales = pd.DataFrame({
#     "product": ["Laptop", "Mobile"]
# })

# feb_sales = pd.DataFrame({
#     "product": ["Tablet", "Watch"]
# })

# combined = pd.concat([jan_sales, feb_sales])


# column-wise concat

df1 = pd.DataFrame({
    "name": ["Arun", "Priya"]
})

df2 = pd.DataFrame({
    "salary": [50000, 60000]
})

combined = pd.concat([df1, df2], axis=1)
print(combined)
# Out:
#     name  salary
# 0   Arun   50000
# 1  Priya   60000

# %%
# # # MULTIPLE KEY MERGING

# # sales1 = pd.DataFrame({
# #     "customer_id": [1, 1],
# #     "product_id": [101, 102],
# #     "qty": [2, 1]
# # })

# # sales2 = pd.DataFrame({
# #     "customer_id": [1, 1],
# #     "product_id": [101, 102],
# #     "price": [500, 700]
# # })


# # merged = pd.merge(
# #     sales1,
# #     sales2,
# #     on=["customer_id", "product_id"]
# # )

# # print(merged)



# # DIFFERENT COLUMN NAMES
# customers = pd.DataFrame({
#     "cust_id": [1, 2],
#     "name": ["Arun", "Priya"]
# })

# orders = pd.DataFrame({
#     "customer_id": [1, 2],
#     "amount": [1000, 2000]
# })


# merged = pd.merge(
#     customers,
#     orders,
#     left_on="cust_id",
#     right_on="customer_id"
# )

# print(merged)


# DUPLICATE COLUMN HANDLING

# df1 = pd.DataFrame({
#     "id": [1],
#     "city": ["Chennai"]
# })

# df2 = pd.DataFrame({
#     "id": [1],
#     "city": ["Mumbai"]
# })


# merged = pd.merge(
#     df1,
#     df2,
#     on="id",
#     suffixes=("_customer", "_shipping")
# )

# print(merged)
# Out:
#    cust_id   name  customer_id  amount
# 0        1   Arun            1    1000
# 1        2  Priya            2    2000

# %%
# jan_sales = pd.DataFrame({
#     "product": ["Laptop", "Mobile"]
# })

# feb_sales = pd.DataFrame({
#     "product": ["Tablet", "Watch"]
# })

# combined = pd.concat([jan_sales, feb_sales])

# print(combined)

# df1 = pd.DataFrame({
#     "name": ["Arun", "Priya"]
# })

# df2 = pd.DataFrame({
#     "salary": [50000, 60000]
# })

# combined = pd.concat([df1, df2], axis=1)

# print(combined)
# Out:
#     name   salary
# 0   Arun      NaN
# 1  Priya      NaN
# 0    NaN  50000.0
# 1    NaN  60000.0
