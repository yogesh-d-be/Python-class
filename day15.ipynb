# %%
import pandas as pd
data = {
    "Date": [
        "2025-01-01", "2025-01-01", "2025-01-02",
        "2025-01-02", "2025-01-03", "2025-01-03"
    ],
    
    "Region": [
        "North", "South", "North",
        "East", "West", "South"
    ],
    
    "Product": [
        "Laptop", "Mobile", "Laptop",
        "Tablet", "Mobile", "Laptop"
    ],
    
    "Salesperson": [
        "Arun", "Priya", "Arun",
        "Kumar", "Priya", "Arun"
    ],
    
    "Sales": [
        50000, 30000, 45000,
        25000, 35000, 40000
    ],
    
    "Quantity": [
        5, 10, 4, 3, 8, 6
    ]
}

df = pd.DataFrame(data)

print(df)

# pd.pivot_table(
#     data,
#     values,
#     index,
#     columns,
#     aggfunc,
#     fill_value
    # margins
# )

# Total Sales by Region
# pt = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     aggfunc="sum"
# )
# print(pt)
# Average Sales by Product

# pt = pd.pivot_table(
#     df,
#     values="Sales",
#     index = "Product",
#     aggfunc="mean"
# )

# print(pt)

# Region vs Product
# pt = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     columns="Product",
#     aggfunc="sum"
# )
# print(pt)
# Count Sales by Region
# pt = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     aggfunc="count"
# )
# print(pt)

# Maximum Sales
# pt = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Salesperson",
#     aggfunc="max"
# )
# print(pt)
# Multiple Aggregation Functions
# pt = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     aggfunc=["sum", "mean", "max"]
# )
# print(pt)
# Multiple Indexes
# pt = pd.pivot_table(
#     df,
#     values="Sales",
#     index=["Region", "Product"],
#     aggfunc="sum"
# )
# print(pt)
# Multiple Columns
# pt = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     columns= ["Product","Salesperson"],
#     aggfunc="sum"
# )
# print(pt)

# HANDLING MISSING VALUES
pt = pd.pivot_table(
    df,
    values="Sales",
    index="Region",
    columns= ["Product","Salesperson"],
    aggfunc="sum",
    fill_value = "-"
)
print(pt)
# Out:
#          Date Region Product Salesperson  Sales  Quantity
# 0  2025-01-01  North  Laptop        Arun  50000         5
# 1  2025-01-01  South  Mobile       Priya  30000        10
# 2  2025-01-02  North  Laptop        Arun  45000         4
# 3  2025-01-02   East  Tablet       Kumar  25000         3
# 4  2025-01-03   West  Mobile       Priya  35000         8
# 5  2025-01-03  South  Laptop        Arun  40000         6
# Product     Laptop Mobile Tablet
# Salesperson   Arun  Priya  Kumar
# Region
# East             -      -  25000
# North        95000      -      -
# South        40000  30000      -
# West             -  35000      -

# %%
# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     aggfunc="sum"
# )

# print(pivot)


# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Product",
#     aggfunc="mean"
# )

# print(pivot)

# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     columns="Product",
#     aggfunc="sum"
# )

# print(pivot)


# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     aggfunc="count"
# )

# print(pivot)

# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Salesperson",
#     aggfunc="max"
# )

# print(pivot)


# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     aggfunc=["sum", "mean", "max"]
# )

# print(pivot)

# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index=["Region", "Product"],
#     aggfunc="sum"
# )

# print(pivot)


# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     columns=["Product", "Salesperson"],
#     aggfunc="sum"
# )

# print(pivot)

# pivot = pd.pivot_table(
#     df,
#     values="Sales",
#     index="Region",
#     columns="Product",
#     aggfunc="sum",
#     fill_value=0
# )

# print(pivot)
