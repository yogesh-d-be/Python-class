# %%
import pandas as pd
import os

print(os.path.exists("./employees.csv"))

print(os.getcwd())

# data = {
#     "Employee": ["John", "Asha", "Rahul", "Priya", "Kumar", "Asha"],
#     "Department": ["IT", "HR", "IT", "Sales", "HR", "HR"],
#     "Age": [25, 30, 28, None, 35, 30],
#     "Salary": [50000, 60000, 55000, 45000, None, 60000],
#     "JoiningDate": [
#         "2022-01-10",
#         "2021-05-15",
#         "2020-07-01",
#         "2023-02-20",
#         "2021-11-11",
#         "2021-05-15"
#     ]
# }

df = pd.read_csv("./employees.csv")

print(df.head())
# Out:
# True
# e:\python-class
#    Name  Age  Salary
# 0  John   25   50000

# %%
# Out:
# True
# e:\python-class
#    Name  Age  Salary
# 0  John   25   50000
# 1  Asha   30   60000
